# %% [markdown]
# <a href="https://colab.research.google.com/github/gilangalfitra/Project-AnalisisData-1000SalesRecord/blob/main/%3CKELOMPOK_5%3E_%3C1000_Sales_Records_Dataset%3E_PROJEK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CLEANSING DATA**

# %%
# AUTHOR  : GILANG ALFITRA
# TANGGAL : 12 JUNI 2023
# TUJUAN  : ANALISIS DATA

# %%
import pandas as pd
import numpy as np

# %%
# !pip install pandasql
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26771 sha256=af9513091b74ca85138eb3d8179d915a080fa2f27da260ac5e9ef8f13569eb29
#   Stored in directory: /root/.cache/pip/wheels/e9/bc/3a/8434bdcccf5779e72894a9b24fecbdcaf97940607eaf4bcdf9
# Successfully built pandasql
# ...

# %%
# IMPORT LIBRARY YANG DIPERLUKAN
import pandasql
from pandasql import sqldf

# %%
# (ISI SENDIRI)
sql_run = lambda q: sqldf(q, globals())

# %%
# (ISI SENDIRI)
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# (ISI SENDIRI)
import csv

# %%
# MOUNTING KE LOKASI DATAFRAME DAN KONVERSI KE DATA KE DATAFRAME
data = pd.read_csv('/content/drive/MyDrive/DataSets_master_10000_Sales_Records.csv')
df = pd.DataFrame(data)

# %%
# MEMANGGIL DATAFRAME
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
# MELIHAT KAREKTERISTIK DARI DATAFRAME
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  object
#  1   Country         10000 non-null  object
#  2   Item Type       10000 non-null  object
#  3   Sales Channel   10000 non-null  object
#  4   Order Priority  10000 non-null  object
#  5   Order Date      10000 non-null  object
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  object
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# MENCARI RECORD YANG BERNILAI 'NULL'

# %%
# MELIHAT RECORD DENGAN NILAI NULL
df.isnull()
# Out:
#       Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0      False    False      False          False           False       False
# 1      False    False      False          False           False       False
# 2      False    False      False          False           False       False
# 3      False    False      False          False           False       False
# 4      False    False      False          False           False       False
# ...      ...      ...        ...            ...             ...         ...
# 9995   False    False      False          False           False       False
# 9996   False    False      False          False           False       False
# 9997   False    False      False          False           False       False
# 9998   False    False      False          False           False       False
# 9999   False    False      False          False           False       False
#
# ...

# %%
# MENGHITUNG RECORD DENGAN NILAI NULL
df.isnull().count()
# Out:
# Region            10000
# Country           10000
# Item Type         10000
# Sales Channel     10000
# Order Priority    10000
# Order Date        10000
# Order ID          10000
# Ship Date         10000
# Units Sold        10000
# Unit Price        10000
# Unit Cost         10000
# Total Revenue     10000
# Total Cost        10000
# Total Profit      10000
# dtype: int64

# %%
# MENGGANTI TIPE DATA OBJECT PADA 'Order Date dan Ship Date' MENJADI DATE TIME
df['Order Date'] = pd.to_datetime(df['Order Date'].str.strip(), format='%M/%d/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'].str.strip(), format='%M/%d/%Y')

# %%
# CEK APAKAH CONVERT BERHASIL
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  object
#  1   Country         10000 non-null  object
#  2   Item Type       10000 non-null  object
#  3   Sales Channel   10000 non-null  object
#  4   Order Priority  10000 non-null  object
#  5   Order Date      10000 non-null  datetime64[ns]
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  datetime64[ns]
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# MENGUBAH TIPE DATA BERHASIL

# %% [markdown]
# **MENGURUTKAN DATA BERDASARKAN KOLOM**

# %%
# VOTE Region terendah ke tertinggi
df_sorted_region = df.sort_values('Region', ascending=True)

# %%
df_sorted_region
# Out:
#                   Region       Country        Item Type Sales Channel  \
# 9999                Asia      Mongolia           Snacks       Offline
# 5883                Asia         India        Household        Online
# 5898                Asia  Turkmenistan       Vegetables       Offline
# 5903                Asia    Uzbekistan        Baby Food        Online
# 5914                Asia         China       Vegetables       Offline
# ...                  ...           ...              ...           ...
# 1988  Sub-Saharan Africa        Uganda           Fruits        Online
# 828   Sub-Saharan Africa       Nigeria             Meat        Online
# 7850  Sub-Saharan Africa  South Africa    Personal Care        Online
# 5178  Sub-Saharan Africa     Swaziland             Meat       Offline
# 0     Sub-Saharan Africa          Chad  Office Supplies        Online
#
#      Order Priority          Order Date   Order ID           Ship Date  \
# ...

# %%
# VOTE Country terendah ke tertinggi
df_sorted_country = df.sort_values('Country', ascending=True)

# %%
df_sorted_country
# Out:
#                             Region      Country        Item Type  \
# 4027  Middle East and North Africa  Afghanistan           Cereal
# 3482  Middle East and North Africa  Afghanistan        Household
# 7775  Middle East and North Africa  Afghanistan           Cereal
# 5976  Middle East and North Africa  Afghanistan             Meat
# 400   Middle East and North Africa  Afghanistan        Household
# ...                            ...          ...              ...
# 4288            Sub-Saharan Africa     Zimbabwe           Cereal
# 5432            Sub-Saharan Africa     Zimbabwe  Office Supplies
# 9541            Sub-Saharan Africa     Zimbabwe           Fruits
# 7640            Sub-Saharan Africa     Zimbabwe          Clothes
# 8080            Sub-Saharan Africa     Zimbabwe           Fruits
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# 4027       Offline              H 2013-01-24 00:07:00  933963477
# ...

# %%
# VOTE Item Type terendah ke tertinggi
df_sorted_item_type = df.sort_values('Item Type', ascending=True)

# %%
df_sorted_item_type
# Out:
#                                  Region                 Country   Item Type  \
# 9697                             Europe                 Ireland   Baby Food
# 4393                             Europe  Bosnia and Herzegovina   Baby Food
# 705                              Europe                Slovakia   Baby Food
# 5100              Australia and Oceania             New Zealand   Baby Food
# 1484  Central America and the Caribbean                Dominica   Baby Food
# ...                                 ...                     ...         ...
# 8344       Middle East and North Africa                  Jordan  Vegetables
# 5516                             Europe              San Marino  Vegetables
# 2391                             Europe                 Ukraine  Vegetables
# 8339                 Sub-Saharan Africa                 Burundi  Vegetables
# 9391                             Europe                 Croatia  Vegetables
#
# ...

# %%
# VOTE Sales Channel terendah ke tertinggi
df_sorted_sales_channel = df.sort_values('Sales Channel', ascending=True)

# %%
df_sorted_sales_channel
# Out:
#                                  Region   Country        Item Type  \
# 9999                               Asia  Mongolia           Snacks
# 7924                             Europe   Andorra    Personal Care
# 4104       Middle East and North Africa    Turkey        Baby Food
# 4102                             Europe    Norway             Meat
# 4101       Middle East and North Africa    Jordan           Snacks
# ...                                 ...       ...              ...
# 4427                               Asia    Bhutan           Snacks
# 4426                             Europe    Serbia             Meat
# 4424       Middle East and North Africa   Algeria  Office Supplies
# 4363                             Europe    Serbia        Beverages
# 4999  Central America and the Caribbean   Grenada    Personal Care
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# 9999       Offline              M 2016-01-12 00:04:00  824410903
# ...

# %%
# VOTE Order Priority terendah ke tertinggi
df_sorted_order_priority = df.sort_values('Order Priority', ascending=True)

# %%
df_sorted_order_priority
# Out:
#                                  Region      Country      Item Type  \
# 4019                             Europe       Serbia  Personal Care
# 8636                             Europe   Luxembourg      Cosmetics
# 5584                             Europe       Russia           Meat
# 8639                             Europe   San Marino        Clothes
# 2303                               Asia   Uzbekistan      Household
# ...                                 ...          ...            ...
# 5377                 Sub-Saharan Africa         Mali      Baby Food
# 5380                 Sub-Saharan Africa     Djibouti      Baby Food
# 5382                 Sub-Saharan Africa   The Gambia         Fruits
# 5391  Central America and the Caribbean  Saint Lucia        Clothes
# 9999                               Asia     Mongolia         Snacks
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# 4019        Online              C 2014-01-12 00:12:00  421887290
# ...

# %%
# VOTE Order ID terendah ke tertinggi
df_sorted_vote_order_id = df.sort_values('Order ID', ascending=True)

# %%
df_sorted_vote_order_id
# Out:
#                                  Region                 Country  \
# 7199       Middle East and North Africa                   Egypt
# 3543                 Sub-Saharan Africa                  Guinea
# 4515                             Europe                 Finland
# 3582              Australia and Oceania                  Tuvalu
# 6727  Central America and the Caribbean                Dominica
# ...                                 ...                     ...
# 1028  Central America and the Caribbean  Saint Kitts and Nevis
# 5007                 Sub-Saharan Africa                    Togo
# 9348                             Europe                  Norway
# 6749  Central America and the Caribbean             The Bahamas
# 1670                             Europe              Montenegro
#
#             Item Type Sales Channel Order Priority          Order Date  \
# 7199           Cereal        Online              H 2013-01-04 00:09:00
# ...

# %%
# VOTE Units Sold terendah ke tertinggi
df_sorted_vote_units_sold = df.sort_values('Units Sold', ascending=True)

# %%
df_sorted_vote_units_sold
# Out:
#                             Region       Country   Item Type Sales Channel  \
# 1936            Sub-Saharan Africa          Togo   Cosmetics       Offline
# 4215                        Europe        Russia   Baby Food       Offline
# 4380                          Asia  Turkmenistan   Beverages        Online
# 4029            Sub-Saharan Africa    Mauritius       Cereal       Offline
# 3721  Middle East and North Africa    Azerbaijan   Baby Food       Offline
# ...                            ...           ...         ...           ...
# 128                           Asia     Sri Lanka  Vegetables       Offline
# 3124                          Asia          Laos   Cosmetics        Online
# 2674            Sub-Saharan Africa          Chad      Snacks       Offline
# 4102                        Europe        Norway        Meat       Offline
# 8268                        Europe       Iceland      Snacks        Online
#
# ...

# %%
# VOTE Unit Price terendah ke tertinggi
df_sorted_vote_unit_price = df.sort_values('Unit Price', ascending=True)

# %%
df_sorted_vote_unit_price
# Out:
#                                  Region               Country  Item Type  \
# 6734  Central America and the Caribbean              Honduras     Fruits
# 3243       Middle East and North Africa  United Arab Emirates     Fruits
# 681                  Sub-Saharan Africa              Cameroon     Fruits
# 8911                 Sub-Saharan Africa            Mauritius      Fruits
# 8910                               Asia           South Korea     Fruits
# ...                                 ...                   ...        ...
# 5874       Middle East and North Africa              Tunisia   Household
# 2580                 Sub-Saharan Africa              Djibouti  Household
# 7679                             Europe                Sweden  Household
# 5910                             Europe          Vatican City  Household
# 8488                               Asia              Thailand  Household
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# ...

# %%
# VOTE Unit Cost terendah ke tertinggi
df_sorted_vote_unit_cost = df.sort_values('Unit Cost', ascending=True)

# %%
df_sorted_vote_unit_cost
# Out:
#                             Region       Country        Item Type  \
# 3745                          Asia    Uzbekistan           Fruits
# 1330            Sub-Saharan Africa        Zambia           Fruits
# 1328  Middle East and North Africa         Egypt           Fruits
# 8427                        Europe       Croatia           Fruits
# 8433  Middle East and North Africa  Saudi Arabia           Fruits
# ...                            ...           ...              ...
# 1827            Sub-Saharan Africa       Burundi  Office Supplies
# 7794                        Europe       Iceland  Office Supplies
# 1850                        Europe      Slovenia  Office Supplies
# 1855            Sub-Saharan Africa        Rwanda  Office Supplies
# 0               Sub-Saharan Africa          Chad  Office Supplies
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# 3745       Offline              H 2012-01-05 00:11:00  709281909
# ...

# %%
# VOTE Total Revenue terendah ke tertinggi
df_sorted_vote_total_revenue = df.sort_values('Total Revenue', ascending=True)

# %%
df_sorted_vote_total_revenue
# Out:
#                                  Region       Country  Item Type  \
# 7160                               Asia   Philippines     Fruits
# 4380                               Asia  Turkmenistan  Beverages
# 4037                 Sub-Saharan Africa         Ghana     Fruits
# 3878  Central America and the Caribbean      Honduras     Fruits
# 4139                               Asia        Bhutan     Fruits
# ...                                 ...           ...        ...
# 8199              Australia and Oceania     Australia  Household
# 6365       Middle East and North Africa         Egypt  Household
# 8672                             Europe    Luxembourg  Household
# 2814       Middle East and North Africa       Lebanon  Household
# 5569                               Asia        Brunei  Household
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# 7160        Online              H 2012-01-25 00:01:00  707994019
# ...

# %%
# VOTE Total Cost terendah ke tertinggi
df_sorted_vote_total_cost = df.sort_values('Total Cost', ascending=True)

# %%
df_sorted_vote_total_cost
# Out:
#                                  Region       Country        Item Type  \
# 7160                               Asia   Philippines           Fruits
# 4380                               Asia  Turkmenistan        Beverages
# 4037                 Sub-Saharan Africa         Ghana           Fruits
# 4139                               Asia        Bhutan           Fruits
# 3878  Central America and the Caribbean      Honduras           Fruits
# ...                                 ...           ...              ...
# 4890                 Sub-Saharan Africa  Sierra Leone  Office Supplies
# 720                  Sub-Saharan Africa         Niger  Office Supplies
# 5360                               Asia         China  Office Supplies
# 5469                 Sub-Saharan Africa  Burkina Faso  Office Supplies
# 4127                             Europe        Poland  Office Supplies
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# ...

# %%
# VOTE Total Profit terendah ke tertinggi
df_sorted_vote_total_profit = df.sort_values('Total Profit', ascending=True)

# %%
df_sorted_vote_total_profit
# Out:
#                                  Region       Country  Item Type  \
# 7160                               Asia   Philippines     Fruits
# 4037                 Sub-Saharan Africa         Ghana     Fruits
# 4380                               Asia  Turkmenistan  Beverages
# 4139                               Asia        Bhutan     Fruits
# 3878  Central America and the Caribbean      Honduras     Fruits
# ...                                 ...           ...        ...
# 8708                             Europe        Sweden  Cosmetics
# 9654                 Sub-Saharan Africa    Mozambique  Cosmetics
# 7265                 Sub-Saharan Africa          Mali  Cosmetics
# 5660       Middle East and North Africa       Somalia  Cosmetics
# 3124                               Asia          Laos  Cosmetics
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# 7160        Online              H 2012-01-25 00:01:00  707994019
# ...

# %% [markdown]
# # **FILTERING DATA MENGGUNAKAN OPERASI LOGIKA**

# %%
filter = df[df['Total Revenue'] >= 1000000]
print("Amount of Total Revenue Gether than 1000000 in the dataset : ", filter.shape[0])
# Out:
# Amount of Total Revenue Gether than 1000000 in the dataset :  4335

# %%
filter2 = df[df['Order Priority'] == 'L']
print("Data of Order Priority = L in the dataset : ", filter2.shape[0])
# Out:
# Data of Order Priority = L in the dataset :  2494

# %%
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority          Order Date  \
# ...

# %%
# Untuk mencari data yang unik di kolom Sales Channel
df['Sales Channel'].unique()
# Out:
# array(['Online', 'Offline'], dtype=object)

# %%
# Untuk mencari data yang unik di kolom Order Priority
df['Order Priority'].unique()
# Out:
# array(['L', 'C', 'H', 'M'], dtype=object)

# %%
# Untuk mencari data yang unik di kolom Item Type
df['Item Type'].unique()
# Out:
# array(['Office Supplies', 'Beverages', 'Vegetables', 'Household',
#        'Baby Food', 'Meat', 'Cereal', 'Clothes', 'Snacks',
#        'Personal Care', 'Cosmetics', 'Fruits'], dtype=object)

# %%
#values_count() digunakan untuk mengembalikan jumlah kemunculan setiap nilai dalam kerangka data atau kolom tertentu
df['Sales Channel'].value_counts()
# Out:
# Online     5061
# Offline    4939
# Name: Sales Channel, dtype: int64

# %%
#filter the dataframe with condition
filter1 = df[df['Units Sold'] >= 5000]
print("Amount of Units Sold Gether than 5000 in the dataset : ", filter1.shape[0])
# Out:
# Amount of Units Sold Gether than 5000 in the dataset :  4957

# %%
filter1.head()
# Out:
#                                Region                           Country  \
# 2        Middle East and North Africa                          Pakistan
# 3                  Sub-Saharan Africa  Democratic Republic of the Congo
# 5                  Sub-Saharan Africa                      South Africa
# 9   Central America and the Caribbean                             Haiti
# 11                             Europe            Bosnia and Herzegovina
#
#           Item Type Sales Channel Order Priority          Order Date  \
# 2        Vegetables       Offline              C 2011-01-13 00:01:00
# 3         Household        Online              C 2012-01-11 00:09:00
# 5         Beverages       Offline              H 2012-01-10 00:07:00
# 9   Office Supplies        Online              C 2015-01-04 00:07:00
# 11        Baby Food       Offline              M 2012-01-20 00:10:00
#
#      Order ID           Ship Date  Units Sold  Unit Price  Unit Cost  \
# ...

# %%
#if you want to filter with "and operator" you can call the each column that you want to filter and wrap with the dataframe brackets
and_operator = df[(df['Sales Channel'] == 'Online') & (df['Units Sold'] > 5000)]
and_operator
# Out:
#                                  Region                           Country  \
# 3                    Sub-Saharan Africa  Democratic Republic of the Congo
# 9     Central America and the Caribbean                             Haiti
# 12                               Europe                           Germany
# 13                                 Asia                             India
# 26                               Europe                            Greece
# ...                                 ...                               ...
# 9981                               Asia                        Kazakhstan
# 9987                 Sub-Saharan Africa                             Ghana
# 9989                 Sub-Saharan Africa                            Rwanda
# 9995                               Asia                              Laos
# 9998                 Sub-Saharan Africa                      South Africa
#
#             Item Type Sales Channel Order Priority          Order Date  \
# ...

# %%
or_operator = df[(df['Sales Channel'] == 'Online') | (df['Units Sold'] > 5000)]
or_operator
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9992         Australia and Oceania                        East Timor
# 9994            Sub-Saharan Africa                            Guinea
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9998            Sub-Saharan Africa                      South Africa
#
#             Item Type Sales Channel Order Priority          Order Date  \
# ...

# %%
and_operator2 = df[(df['Sales Channel'] == 'Online') & (df['Units Sold'] > 5000) & (df['Order Priority'] == 'M')]
and_operator2
# Out:
#                             Region       Country        Item Type  \
# 31                          Europe   Switzerland    Personal Care
# 35    Middle East and North Africa    Azerbaijan        Cosmetics
# 50                          Europe      Slovenia        Cosmetics
# 52              Sub-Saharan Africa  South Africa           Cereal
# 65              Sub-Saharan Africa    Mauritius     Personal Care
# ...                            ...           ...              ...
# 9880                          Asia  Turkmenistan  Office Supplies
# 9893         Australia and Oceania        Samoa        Vegetables
# 9907                          Asia    Uzbekistan        Cosmetics
# 9940                          Asia        Bhutan           Cereal
# 9975                 North America        Mexico           Cereal
#
#      Sales Channel Order Priority          Order Date   Order ID  \
# 31          Online              M 2011-01-05 00:08:00  392325484
# ...

# %%
# Manipulasi string bisa mendapatkan filter berdasarkan pola
#dan Anda harus mengurung bingkai data untuk mendapatkan keluaran filter
th = df[df['Sales Channel'].str.contains(pat='Online')]
th[['Country','Item Type', 'Sales Channel', 'Order ID', 'Units Sold','Total Profit']].head()
# Out:
#                             Country        Item Type Sales Channel   Order ID  \
# 0                              Chad  Office Supplies        Online  292494523
# 1                            Latvia        Beverages        Online  361825549
# 3  Democratic Republic of the Congo        Household        Online  500364005
# 4                    Czech Republic        Beverages        Online  127481591
# 6                              Laos       Vegetables        Online  844532620
#
#    Units Sold  Total Profit
# 0        4484     566105.00
# 1        1075      16834.50
# 3        7683    1273303.59
# 4        3491      54669.06
# 6        4825     304602.25

# %%
#kolom rename Anda dapat menggunakan kamus untuk menemukan kunci untuk nama kolom lama dan nilai untuk nama kolom baru
df_new = df.rename(columns={'Item Type': 'Tipe Item', 'Units Sold': 'Unit Terjual', 'Total Profit': 'Total Keuntungan'})
df_new[['Tipe Item','Unit Terjual', 'Total Keuntungan']].head()
# Out:
#          Tipe Item  Unit Terjual  Total Keuntungan
# 0  Office Supplies          4484         566105.00
# 1        Beverages          1075          16834.50
# 2       Vegetables          6515         411291.95
# 3        Household          7683        1273303.59
# 4        Beverages          3491          54669.06

# %%
#grouping dataframe dimulai dari kolom yang bisa anda lihat insightnya
#dan pilih kolom yang ingin Anda gabungkan dengan kolom pertama
group_type = df.groupby(['Item Type'])['Units Sold'].sum()
group_type
# Out:
# Item Type
# Baby Food          4197006
# Beverages          3910436
# Cereal             4203394
# Clothes            4352350
# Cosmetics          4103290
# Fruits             4055921
# Household          4336803
# Meat               3985390
# Office Supplies    4120263
# Personal Care      4402827
# Snacks             4122781
# Vegetables         4238098
# Name: Units Sold, dtype: int64

# %% [markdown]
# # **CONDITIONAL**

# %%
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority          Order Date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          10000 non-null  object
#  1   Country         10000 non-null  object
#  2   Item Type       10000 non-null  object
#  3   Sales Channel   10000 non-null  object
#  4   Order Priority  10000 non-null  object
#  5   Order Date      10000 non-null  datetime64[ns]
#  6   Order ID        10000 non-null  int64
#  7   Ship Date       10000 non-null  datetime64[ns]
#  8   Units Sold      10000 non-null  int64
#  9   Unit Price      10000 non-null  float64
#  10  Unit Cost       10000 non-null  float64
#  11  Total Revenue   10000 non-null  float64
#  12  Total Cost      10000 non-null  float64
#  13  Total Profit    10000 non-null  float64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
## CONDITIONAL IF
profit = float(input("Total Profit : "))

if (profit >= 1000000):
  print("Total profit lebih dari 1000000")

elif (500000 <= profit < 1000000):
  print("Total profit kurang dari sama dengan 500000 sampai 999999")

elif (100000 <= profit < 500000):
  print("Total profit kurang dari sama dengan 100000 sampai 499999")

elif (0 < profit < 100000):
  print("Total profit kurang dari sama dengan 100000 sampai 499999")

else:
  print("Anda tidak memiliki profit")
# Out:
# Total Profit : 20000
# Total profit kurang dari sama dengan 100000 sampai 499999

# %% [markdown]
# # **FUNCTION**

# %%
df
# Out:
#                             Region                           Country  \
# 0               Sub-Saharan Africa                              Chad
# 1                           Europe                            Latvia
# 2     Middle East and North Africa                          Pakistan
# 3               Sub-Saharan Africa  Democratic Republic of the Congo
# 4                           Europe                    Czech Republic
# ...                            ...                               ...
# 9995                          Asia                              Laos
# 9996                        Europe                     Liechtenstein
# 9997            Sub-Saharan Africa  Democratic Republic of the Congo
# 9998            Sub-Saharan Africa                      South Africa
# 9999                          Asia                          Mongolia
#
#             Item Type Sales Channel Order Priority          Order Date  \
# ...

# %%
def sort_dataframe(df, column, ascending=True):
  sorted_df = df.sort_values(by=column, ascending=ascending)
  return sorted_df
sorted_df = sort_dataframe(df, 'Order Priority', ascending=True)
sorted_df.head()
# Out:
#       Region     Country      Item Type Sales Channel Order Priority  \
# 4019  Europe      Serbia  Personal Care        Online              C
# 8636  Europe  Luxembourg      Cosmetics       Offline              C
# 5584  Europe      Russia           Meat       Offline              C
# 8639  Europe  San Marino        Clothes        Online              C
# 2303    Asia  Uzbekistan      Household        Online              C
#
#               Order Date   Order ID           Ship Date  Units Sold  \
# 4019 2014-01-12 00:12:00  421887290 2014-01-30 00:12:00        4679
# 8636 2012-01-15 00:12:00  202157723 2013-01-18 00:01:00        1818
# 5584 2014-01-20 00:07:00  747088181 2014-01-28 00:07:00        8850
# 8639 2016-01-15 00:08:00  414037215 2016-01-05 00:09:00        1668
# 2303 2017-01-29 00:01:00  728603255 2017-01-09 00:03:00        8749
#
#       Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 4019       81.73      56.67      382414.67   265158.93     117255.74
# ...

# %% [markdown]
# # **VISUALISASI**

# %%
#sort_values() default dapat mengembalikan output menurun
group_reg = df.groupby(['Item Type'])['Units Sold'].mean().sort_values(ascending=False)
group_reg.plot(kind='bar', title='Item Type With The Highest Average Units Sold')
# Out:
# <Axes: title={'center': 'Item Type With The Highest Average Units Sold'}, xlabel='Item Type'>
